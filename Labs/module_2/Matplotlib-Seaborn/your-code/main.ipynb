# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y , label='linear', linewidth=3)
plt.plot(x,z, label='quadratic', linewidth=3)

plt.legend()
plt.title('Linear vs Quadratic')

plt.xlabel('x axis')
plt.grid()
plt.show() #to stop changes

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axes=plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y, label='linear', linewidth=3)
axes[1].plot(x,z, label='quadratic', linewidth=3)

axes[0].set_xlabel('x axis')
axes[1].set_xlabel('x axis')

axes[0].set_title('Linear')
axes[1].set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, axes=plt.subplots(nrows=1, ncols=2, figsize=(20,6))

axes[0].plot(x,y, label='linear', linewidth=3)
axes[1].plot(x,z, label='quadratic', linewidth=3)

axes[0].set_xlabel('x axis')
axes[1].set_xlabel('x axis')

axes[0].set_title('Linear')
axes[1].set_title('Quadratic')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
import math

# %%
x = np.arange(0,100)
y1 = 𝑥**2
y2 = np.exp(x)

fig, axes=plt.subplots(nrows=1, ncols=2, figsize=(5,5))

axes[0].plot(x,y1, linewidth=3)
axes[1].plot(x,y2, linewidth=3)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
x = np.arange(0,100)
y1 = 𝑥**2
y2 = np.exp(x)

fig, axes=plt.subplots(nrows=1, ncols=2, figsize=(5,5))

axes[0].plot(x,y1, linewidth=3)
axes[1].plot(x,y2, linewidth=3)

axes[0].set_ylabel('x**2')
axes[1].set_ylabel('np.exp(x)')

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r'C:\Users\Arthur\248_Repo\Labs\module_2\Matplotlib-Seaborn\your-code\Fitbit2.csv')

# %%
fitbit.sample(10)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 179  2015-11-03            2403   6269      4.66       9               1.43
# 73   2015-07-20            3278  13702     10.18      21             708.00
# 318  2016-03-20            2731   6754      5.02       1             564.00
# 23   2015-05-31            3533  18995     14.11      12             660.00
# 41   2015-06-18            3425  15217     11.31      61             641.00
# 11   2015-05-19            2911  12425      9.23      14             827.00
# 293  2016-02-24            2933   8307      6.17      12             762.00
# 63   2015-07-10            3134  10644      7.91      15             683.00
# 185  2015-11-09            2828     95      7.06       0             756.00
# 272  2016-02-04            2037   2449      1.87       0             821.00
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 179                      10                      0                    0
# 73                      246                     48                   43
# 318                     315                      0                    0
# 23                      269                     86                   43
# 41                      280                     44                   59
# 11                      186                     18                   54
# 293                     195                     25                   37
# 63                      283                     36                   17
# 185                     218                     28                   13
# 272                      80                      0                    0
#
#      Activity Calories  ...  Distance_miles       Days  Days_encoded  \
# 179                370  ...        2.895589    Tuesday           1.0
# 73                1775  ...        6.325557     Monday           0.0
# 318               1237  ...        3.119282     Sunday           6.0
# 23                2092  ...        8.767545     Sunday           6.0
# 41                1974  ...        7.027706   Thursday           3.0
# 11                1351  ...        5.735254    Tuesday           1.0
# 293               1305  ...        3.833859  Wednesday           2.0
# 63                1606  ...        4.915045     Friday           4.0
# 185               1225  ...        4.386879     Monday           0.0
# 272               3370  ...        1.161964   Thursday           3.0
#
#      Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# 179                1     0.000000         0.000000         4.600000
# 73                 1     6.966667        95.433790         6.033333
# 318                0     6.383333        89.695550         7.250000
# 23                 0     7.100000        86.060606         5.466667
# 41                 1     2.816667        86.224490         7.016667
# 11                 1     6.133333        87.619048         2.783333
# 293                1     7.283333        95.206972         4.050000
# 63                 1     6.133333        85.382831         9.166667
# 185                1     5.750000        89.378238         0.000000
# 272                1     6.833333        94.036697         4.133333
#
#      Yesterday_sleep_efficiency    Months  Months_encoded
# 179                   90.789474  November              11
# 73                    92.111959      July               7
# 318                   89.876033     March               3
# 23                    85.863874       May               5
# 41                    93.973214      June               6
# 11                    92.777778       May               5
# 293                   91.353383  February               2
# 63                    92.592593      July               7
# 185                    0.000000  November              11
# 272                   88.571429  February               2
#
# [10 rows x 24 columns]

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
a = fitbit['Steps']
b = fitbit['Months_encoded']
c = fitbit['Work_or_Weekend']


df.groupby('state')['name'].nunique().plot(kind='bar')
plt.show()


plt.scatter(b, mean(a), label='', linewidth=3)

#plt.xticks(a, labels, rotation ='vertical')
#fig, axes=plt.subplots(nrows=1, ncols=2, figsize=(12,4))
#axes[0].scatter(x,z, linewidth=3)
#axes[1].scatter(x,y, linewidth=3)



  
# You can specify a rotation for the tick 
# labels in degrees or with keywords. 


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-69bb9fcaf899> in <module>
#       7
#       8
# ----> 9 plt.scatter(b, mean(a), label='', linewidth=3)
#      10
#      11 #plt.xticks(a, labels, rotation ='vertical')
#
# NameError: name 'mean' is not defined

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
